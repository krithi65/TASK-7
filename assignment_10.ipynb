# %% [markdown]
# <a href="https://colab.research.google.com/github/krithi65/TASK-7/blob/main/assignment_10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd 
df=pd.read_csv("/content/glass.data",names=["Id number","RI","Na","Mg","Al","Si","K","Ca","Ba","Fe","Type of glass"])
df.head()
# Out:
#    Id number       RI     Na    Mg    Al     Si     K    Ca   Ba   Fe  \
# 0          1  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.0  0.0
# 1          2  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.0  0.0
# 2          3  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.0  0.0
# 3          4  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.0  0.0
# 4          5  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.0  0.0
#
#    Type of glass
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1

# %%
#1.clean
df.shape
# Out:
# (214, 11)

# %%
df.isnull().sum()
# Out:
# Id number        0
# RI               0
# Na               0
# Mg               0
# Al               0
# Si               0
# K                0
# Ca               0
# Ba               0
# Fe               0
# Type of glass    0
# dtype: int64

# %%
df.dtypes
# Out:
# Id number          int64
# RI               float64
# Na               float64
# Mg               float64
# Al               float64
# Si               float64
# K                float64
# Ca               float64
# Ba               float64
# Fe               float64
# Type of glass      int64
# dtype: object

# %%
df=df.drop("Id number",axis=1)
df
# Out:
#           RI     Na    Mg    Al     Si     K    Ca    Ba   Fe  Type of glass
# 0    1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.0              1
# 1    1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.0              1
# 2    1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.0              1
# 3    1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.0              1
# 4    1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.0              1
# ..       ...    ...   ...   ...    ...   ...   ...   ...  ...            ...
# 209  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06  0.0              7
# 210  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59  0.0              7
# 211  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64  0.0              7
# 212  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57  0.0              7
# 213  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67  0.0              7
#
# [214 rows x 10 columns]

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report
from scipy.spatial import distance

# %%
#Knn performed in two different models and standatized
train = pd.read_csv("/content/train.txt", header=None)
train.columns = ['ID number', 'RI', 'Na', 'Mg', 'Al', 'Si', 'K', 'Ca', 'Ba', 'Fe', 'Type of glass']

# %%
#ID is unique and so dropped
train=train.drop("ID number",axis=1)

# %%
#Knn performed in two different models and standatized
test = pd.read_csv("/content/test.txt", header=None)
test.columns = ['ID number', 'RI', 'Na', 'Mg', 'Al', 'Si', 'K', 'Ca', 'Ba', 'Fe', 'Type of glass']

# %%
#ID is unique and so dropped
test=test.drop("ID number",axis=1)

# %%
train.head(5)
# Out:
#         RI     Na    Mg    Al     Si     K    Ca   Ba   Fe  Type of glass
# 0  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.0  0.0              1
# 1  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.0  0.0              1
# 2  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.0  0.0              1
# 3  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.0  0.0              1
# 4  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.0  0.0              1

# %%
test.head(5)
# Out:
#         RI     Na    Mg    Al     Si     K     Ca   Ba    Fe  Type of glass
# 0  1.52152  13.05  3.65  0.87  72.32  0.19   9.85  0.0  0.17              1
# 1  1.52152  13.12  3.58  0.90  72.20  0.23   9.82  0.0  0.16              1
# 2  1.52300  13.31  3.58  0.82  71.99  0.12  10.17  0.0  0.03              1
# 3  1.51709  13.00  3.47  1.79  72.72  0.66   8.18  0.0  0.00              2
# 4  1.51660  12.99  3.18  1.23  72.97  0.58   8.81  0.0  0.24              2

# %%
train.shape
# Out:
# (196, 10)

# %%
test.shape
# Out:
# (18, 10)

# %%
train.describe()
# Out:
#                RI          Na          Mg          Al          Si           K  \
# count  196.000000  196.000000  196.000000  196.000000  196.000000  196.000000
# mean     1.518524   13.310918    2.931071    1.377041   72.591633    0.520153
# std      0.003103    0.755417    1.243488    0.449946    0.766336    0.645038
# min      1.511150   10.730000    0.000000    0.290000   69.810000    0.000000
# 25%      1.516645   12.870000    2.865000    1.177500   72.215000    0.190000
# 50%      1.517790   13.240000    3.500000    1.340000   72.745000    0.560000
# 75%      1.519347   13.690000    3.612500    1.560000   73.030000    0.610000
# max      1.533930   17.380000    4.490000    3.500000   75.410000    6.210000
#
#                Ca          Ba          Fe  Type of glass
# count  196.000000  196.000000  196.000000     196.000000
# mean     8.987500    0.088622    0.062194       2.392857
# std      1.471372    0.374327    0.100245       1.743486
# min      5.430000    0.000000    0.000000       1.000000
# 25%      8.217500    0.000000    0.000000       1.000000
# 50%      8.595000    0.000000    0.000000       2.000000
# 75%      9.275000    0.000000    0.110000       3.000000
# max     16.190000    3.150000    0.510000       7.000000

# %%
def standardize (df):
    for col in df.columns:
        if col != "Type of glass": # Don't standardize the categories
            df[col] = (df[col] - df[col].mean())/df[col].std()
    return df
train = standardize(train)
test = standardize(test)

# %%
# k = 8 neighbors
euclid_model = KNeighborsClassifier(n_neighbors=8, metric=distance.sqeuclidean) # Square Euclidean distance model
manhattan_model = KNeighborsClassifier(n_neighbors=8, metric=distance.cityblock) # Manhattan distance model
x_train = train.drop(["Type of glass"], axis=1)
y_train = train["Type of glass"]
euclid_model.fit(x_train,y_train) # Train models
manhattan_model.fit(x_train, y_train)
x_test = test.drop("Type of glass", axis=1) 
y_test = test["Type of glass"]

# %%
# Make predictions
manhattan_predictions = manhattan_model.predict(x_test)
euclid_predictions = euclid_model.predict(x_test) 
df = pd.DataFrame({'actual': y_test, 'manhattan': manhattan_predictions, 'euclid': euclid_predictions})
df.head()
# Out:
#    actual  manhattan  euclid
# 0       1          1       1
# 1       1          1       1
# 2       1          1       1
# 3       2          2       2
# 4       2          1       1

# %%
manhattan_count = len(df.loc[df['manhattan'] == df['actual']])
euclid_count = len(df.loc[df['euclid'] == df['actual']])
print('Manhattan Accuracy: {}%'.format(round(100*manhattan_count/len(df), 2)))
print(classification_report(y_test, manhattan_predictions, target_names=df['actual'].astype(str).unique()))
print ('\n')
print('Square Euclidean Accuracy: {}%'.format(round(100*euclid_count/len(df), 2)))
print(classification_report(y_test, euclid_predictions, target_names=df['actual'].astype(str).unique()))
# Out:
# Manhattan Accuracy: 61.11%
#               precision    recall  f1-score   support
#
#            1       0.50      1.00      0.67         3
#            2       0.25      0.33      0.29         3
#            3       0.00      0.00      0.00         3
#            5       1.00      0.67      0.80         3
#            6       0.75      1.00      0.86         3
#            7       1.00      0.67      0.80         3
#
#     accuracy                           0.61        18
#    macro avg       0.58      0.61      0.57        18
# weighted avg       0.58      0.61      0.57        18
#
#
#
# Square Euclidean Accuracy: 55.56%
#               precision    recall  f1-score   support
#
#            1       0.50      1.00      0.67         3
#            2       0.29      0.67      0.40         3
#            3       0.00      0.00      0.00         3
#            5       1.00      0.33      0.50         3
#            6       1.00      0.33      0.50         3
#            7       1.00      1.00      1.00         3
#
#     accuracy                           0.56        18
#    macro avg       0.63      0.56      0.51        18
# weighted avg       0.63      0.56      0.51        18
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
